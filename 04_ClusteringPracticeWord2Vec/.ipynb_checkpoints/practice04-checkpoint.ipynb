# %%
import pandas as pd
import numpy as np
import nltk
from pprint import pprint

from nltk.corpus import stopwords
# if this is first time you use nltk, please open terminal and type codes bellow 
#   >>> import nltk
#   >>> nltk.download('stopwords')
#   >>> nltk.download('punkt')

stops = set(stopwords.words('english'))
import string
puns = string.punctuation

# %% [markdown]
# # Word2Vec
# 1. 簡介
#
#     Word2Vec其實是Word to Vector的簡稱，意在將每一個字轉換成一條向量，並讓這字的語意透過這條向量描繪出來。早期做自然語言處理時，很難對讓電腦對詞背後的意思有更深一層的理解，因此詞與詞之間的關係很難被挖掘出來，像是相似詞、相反詞、對應詞等，因此Word2Vec在這樣的背景下產生就顯得極其珍貴。
#
#
# 2. 作用&賣點
#     1. 它可以找到相似的字。
#     2. 它可以加減，像是Taiwan-Taipei=Germany-Berlin。
#
# 3. 訓練方法: 參照[這篇網誌](https://goatwang.github.io/2017/06/06/Train-Wiki-Corpus-by-gensim-Word2vec/)
#
# 4. 已經訓練好的model:
#     1. [Various Models](http://ahogrammer.com/2017/01/20/the-list-of-pretrained-word-embeddings/)
#     2. 本課程使用之[GloVe Word2Vec](https://nlp.stanford.edu/projects/glove/)(時間考量已經壓縮過，只留下這個文件中會用到的字)。
#
# 5. 專案: 將e-commerce商品標籤分群

# %% [markdown]
# # Load Data

# %%
with open('all_categories.list', 'r', encoding='utf8') as f:
    all_categories = np.array(eval(f.read()))
print("商品標籤個數:", len(all_categories))
print("前10個商品標籤:", all_categories[:10])
# Out:
# 商品標籤個數: 910
# 前10個商品標籤: ['Small Animal' 'Kitchen' 'Fragrance' 'Track & Sweat Suits' 'Wallet'
#  'Favors' 'Quilts' 'Sticker' 'Pets' 'Skirt']

# %%
tr='ABCDEFGHIJK'
tf = tr.split('DEF')
print(tf)
# Out:
# ['ABC', 'GHIJK']

# %%
word_vec_mapping = {}
path = "glove.twitter.27B.50d.txt"

# 打開上述檔案，並將每一行中的第一個詞作為key，後面的數字做為向量，加入到word_vec_mapping
with open(path, 'r', encoding='utf8') as f:  ## 這個文檔的格式是一行一個字並配上他的向量，以空白鍵分隔
    for line in f:  
        #=============your works starts===============#
        tokens = line.split()
        token = tokens[0] ## 第一個token就是詞彙
        vec = tokens[1:]  ## 後面的token向量
        word_vec_mapping[token] = np.array(vec, dtype=np.float32)
        #==============your works ends================#
    for line in f:  
        tokens = line.split('M')
    #     f.close()
    print(tokens[:5])
        
print(word_vec_mapping[token])       
        
vec_dimensions = len(word_vec_mapping.get('men'))
# print("vec_dimensions:", vec_dimensions)
# print("word_vec_mapping length:", len(list(word_vec_mapping.items())))
# pprint(list(word_vec_mapping.items())[:5])
# vec_dimensions: 50
# word_vec_mapping length: 947
# [('shoes',
#   array([-0.75313002, -1.78719997,  0.14522   , -0.29681   ,  0.12436   ,
#        -0.40922999,  1.22679996,  0.50806999,  0.27913001,  0.34277001,
#        -0.013902  ,  1.52499998, -3.44880009,  1.05630004, -0.49985   ,
# Out:
# ['to', '0.5496399998664856', '0.03275199979543686', '0.19354000687599182', '-0.5111899971961975']
# [ 0.54964   0.032752  0.19354  -0.51119  -0.39483  -0.17643   0.49603
#  -0.089685  0.27531  -1.0332   -0.80488  -0.57278  -6.2888   -0.15977
#   0.21716  -0.19869  -0.27966  -0.14035  -0.58645  -0.75832   0.4009
#   0.35394  -0.27532   0.37569  -0.34936  -0.28569   0.49475   0.79527
#   0.84019   0.29181   1.0009    0.36752  -0.12441  -0.22999   0.37812
#   0.2078    0.28736  -0.16952  -0.88277  -0.15059  -1.8376    0.71666
#   0.22428  -0.35486   0.21687  -0.26787  -0.81521   0.21378   0.23067
#   0.20011 ]

# %% [markdown]
# # Tokenize & Doc2Vec

# %%
# 將每一個句子(商品類別)的詞彙
# 1. 切割開來
# 2. 去掉停用字(set(stopwords.words('english')))
# 3. 去掉標點符號(string.punctuation)
# 4. 轉小寫

def tokenize(Doc):
    if pd.notnull(Doc):
        # 使用nltk.wordpunct_tokenize將Doc切開
        # 去掉停用字與標點符號，並轉小寫
        #=============your works starts===============#
        tokens = nltk.wordpunct_tokenize(Doc)
        words = [
            t.lower()
            for t in tokens
            if t not in set(stopwords.words('english')) and t not in string.punctuation ]
        #==============your works ends================#
        return words
    else:
        return None
    
print("before tokenize:", all_categories[0])
print("after tokenize:", tokenize(all_categories[0]))
print("before tokenize:", all_categories[3])
print("after tokenize:", tokenize(all_categories[3]))
# before tokenize: Small Animal
# after tokenize: ['small', 'animal']
# before tokenize: Track & Sweat Suits
# after tokenize: ['track', 'sweat', 'suits']
# Out:
# before tokenize: Small Animal
# after tokenize: ['small', 'animal']
# before tokenize: Track & Sweat Suits
# after tokenize: ['track', 'sweat', 'suits']

# %%
test_arr = np.array([
    [1,2,3,4],
    [4,5,6,7],
    [7,8,9,10]
])
# 請將test_arr中的三個array做element-wise的平均
#=============your works starts===============#
test_out = np.average(test_arr,axis=0)

# test_out = np.average(test_arr,axis=1)
#==============your works ends================#

print(test_out)
# [4. 5. 6. 7.]
# Out:
# [4. 5. 6. 7.]

# %%
word_vec_mapping.keys()
# Out:
# dict_keys(['protection', 'headsets', 'jackets', 'cart', 'seats', 'filters', 'ornaments', 'work', 'cropped', 'strength', 'wind', 'warmers', 'items', 'dead', 'slim', 'coaster', 'crafts', 'kids', 'jewelry', 'school', 'protectors', 'coolers', 'belt', 'vest', 'smartphones', 'balls', 'stringed', 'ray', 'seat', 'loss', 'tag', 'biography', 'cowl', 'merchandise', 'nail', 'subwoofers', 'holidays', 'leggings', 'valentine', 'bowls', 'literature', 'dvd', 'scale', 'slipcovers', 'cookware', 'shirts', 'writing', 'containers', 'fi', 'flatware', 'piece', 'hockey', 'diapering', 'animal', 'doll', 'trading', 'rv', 'sticker', 'pencil', 'drawings', 'math', 'pouch', 'tests', 'suit', 'messenger', 'dolls', 'jeans', 'hooded', 'racquets', 'bike', 'camcorders', 'studio', 'porcelain', 'cross', 'table', 'keyboards', 'origami', 'panties', 'diaper', 'bowling', 'bagg
# %%
def doc2vec(doc, word2vec=word_vec_mapping):
    if pd.notnull(doc):
        # 使用剛剛定義好的tokenize函式tokenize doc，並指派到terms
        # 找出每一個詞彙的代表向量(word_vec_mapping)
        # 並平均(element-wise)所有出現的詞彙向量(注意axis=0)，作為doc的代表向量
        #=============your works starts===============#
        terms = tokenize(doc)
        termvecs = [word_vec_mapping.get(t) for t in terms if t in word_vec_mapping.keys()]
        docvec = np.average(termvecs,axis=0)
        #==============your works ends================#
    
    if np.sum(np.isnan(docvec)) > 0:
        ## 若找不到對應的詞向量，則給一條全部為零的向量，長度為原詞彙代表向量的長度(vec_dimensions)
        #=============your works starts===============#
        docvec= np.zeros(vec_dimensions,)
        #==============your works ends================#
    return docvec

print("before tokenize:", all_categories[3])
print("output shape", doc2vec(all_categories[3]).shape)
print("after tokenize:", doc2vec(all_categories[3])[:5])
print("before tokenize:", all_categories[70])
print("output shape", doc2vec(all_categories[70]).shape)
print("after tokenize:", doc2vec(all_categories[70])[:5])
# before tokenize: Track & Sweat Suits
# output shape (50,)
# after tokenize: [-0.76383996 -0.49650002  0.23154134 -0.16717     0.42855397]
# before tokenize: Teethers
# output shape (50,)
# after tokenize: [0. 0. 0. 0. 0.]
# Out:
# before tokenize: Track & Sweat Suits
# output shape (50,)
# after tokenize: [-0.76383996 -0.49650002  0.23154134 -0.16717     0.42855397]
# before tokenize: Teethers
# output shape (50,)
# after tokenize: [0. 0. 0. 0. 0.]

# %%
tt = (doc2vec(c) for c in all_categories)
np.array(tt)

# list(map(doc2vec,all_categories))
# Out:
# array(<generator object <genexpr> at 0x0000013CFEF0DE08>, dtype=object)

# %%
# 將doc2vec應用到all_categories中的每一個元素上
#=============your works starts===============#
cat_vecs = np.array(list(map(doc2vec,all_categories)))
#==============your works ends================#

print("cat_vecs length:", len(cat_vecs))
print(cat_vecs[3][:5])
print(cat_vecs.shape)
# cat_vecs length: 910
# [-0.76383996 -0.49650002  0.23154134 -0.16717     0.42855397]
# (910, 50)
# Out:
# c:\python\python36\lib\site-packages\numpy\lib\function_base.py:392: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# c:\python\python36\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# cat_vecs length: 910
# [-0.76383996 -0.49650002  0.23154134 -0.16717     0.42855397]
# (910, 50)

# %% [markdown]
# # Clustering

# %%
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import DBSCAN
from collections import Counter
X = cat_vecs
n_clusters= 20

# %% [markdown]
# ## K means

# %%
# 請使用kmeans將商品類別分成20類
#=============your works starts===============#
kmeans = KMeans(n_clusters=20)
all_categories_labels_kmeans = kmeans.fit_predict(X)
#==============your works ends================#

for i in range(3):
    print(";;".join(all_categories[all_categories_labels_kmeans==i]))
    print("====================================")
# Out:
# =============

# %% [markdown]
# ## Hireachy(average link)

# %%
# 請使用hierachical(average link)將商品類別分成20類
#=============your works starts===============#
hierachy = AgglomerativeClustering(n_clusters=20,linkage='average')
all_categories_labels_average = hierachy.fit_predict(X)
#==============your works ends================#


for i in range(3):
    print(";;".join(all_categories[all_categories_labels_average==i]))
    print("=============")
# Out:
# Athletic Training;;Boxing & MMA;;Lacrosse;;Hockey;;Badminton;;Bowl;;Varsity;;Team Sports;;Athletic;;Volleyball;;MLB;;NBA;;Games;;Game;;Basket;;Football;;Bowling;;Pitcher;;Tennis & Racquets;;Cup;;Baseball & Softball;;Fans;;Baseball;;Sports;;Soccer;;Bowls;;NHL;;Fixture;;NFL;;NCAA;;Basketball
# =============
# Dusting;;Waxing;;Thermometers;;Oils & Fluids;;Toothbrushes;;Sponges;;Brushes & Applicators;;Brushes;;Conditioners;;Mopping;;Televisions;;Cables & Adapters;;Nasal Aspirators;;Batteries;;Binoculars & Telescopes;;Magnets;;Soaps & Cleansers;;Cleansers;;Microwaves;;Headsets;;Shampoos;;Sweeping;;Refrigerators;;Powders & Lotions;;Computers & Tablets;;Gadgets;;Laptops & Netbooks;;Keyboards;;Washers & Dryers;;Vests
# =============
# Eyes;;Feet;;Sleep Positioners;;Lips;;Relaxed
# =============

# %% [markdown]
# ## Hireachy(complete link)

# %%
# 請使用hierachical(complete link)將商品類別分成20類
#=============your works starts===============#
hierachy = AgglomerativeClustering(n_clusters=20,linkage='complete')
all_categories_labels_complete = hierachy.fit_predict(X)
#==============your works ends================#


for i in range(0,5):
    print(";;".join(all_categories[all_categories_labels_complete==i]))
    print("==========================")
# Out:
# Kitchen;;Photo Albums & Frames;;Plush;;Storage & Organization;;Knitting Supplies;;Puzzles;;Baskets & Bins;;Yarn;;Baguette;;Paintings;;Crafting;;Storage & Containers;;Garage Storage & Organization;;Home Decor;;Knitting;;Kitchen Storage & Organization;;Outdoor;;Bouquets;;Frame;;Dolls and Miniatures;;Ceramic;;Nursery;;Carving;;Cleaning;;Kids' Furniture;;Puzzle;;Maternity Pillows;;Blankets & Throws;;Sculptures;;Other Furniture;;Patterns;;Dishes;;Washcloths & Towels;;Ornaments;;Photographs;;Peasant;;Home Office Furniture;;Bathroom Storage & Organization;;Kitchen & Table Linens;;Origami;;Hobbies;;Bedroom Furniture;;Antique;;Scale Dollhouse Miniature;;Storage Cabinets;;Mattress Pads;;Home Bar Furniture;;Bath Rugs;;Figurine;;Pillows & Stools;;Artwork;;Crochet;;Decorating;;Teacup;;Pillow;;Sewing;;Planter;;Table;;Pillows;;Baskets;;Indoor;;Figurines;;Cleaning Supplies;;Fabric;;Comforters & Sets;;Laundry Storage & Organization;;Stuffed Animals & Plush;;Collages;;Hawaiian;;Drawings;;Furniture;;Bathroom
Women;;Frame;;Home Décor;;Tricycles, Scooters & Wagons;;Cream and Sugar Set;;Dolls and Miniatures;;Signs;;Cookbook;;Ceramic;;Magic;;Suits & Blazers;;Yoga & Pilates;;Women's Accessories;;Slipcovers;;Denim;;Patchwork;;MLB;;New Year's;;Home;;Work & Safety;;Travel Bathing Kits;;Polo;;Water Coolers & Filters;;Finding;;Boys 2T-5T;;Replacement Parts;;Space Heaters;;Car Video;;Hair Loss Products;;Sandals;;Nursery;;Cleats;;Cage;;Kids' Home Store;;Home Décor Accents;;Travel Systems;;Totes & Shoppers;;Candle Holder;;Shampoo Plus Conditioner;;Nursery Bedding;;Carving;;Day of the Dead;;Cookware;;Dining & Entertaining;;Wallets;;Tuxedo;;Cleaning;;Outdoor Safety;;Lips;;Bottle-Feeding;;Tank;;Snowsuits & Bibs;;Music;;Jean Jacket;;St Patrick's;;Kids' Furniture;;Magazines;;Puzzle;;Other;;Video Game;;75 To 100 Years;;Ceramics and Pottery;;Conditioners;;Joggers;;Maternity Pillows;;Backpacks & Carriers;;Coats & Jackets;;Art;;Biographies & Memoirs;;Accessories;;Wristlet;;Slim, Skinny;;Earrings;;Mopping;;Trash Bags;;Gear;;Shampoo;;Pet Lover;;Boxes;;Boots;;Capris, Cropped;;Vase;;Home Fragrance;;Sun;;Dance;;Televisions;;Paint, Body & Trim;;Learning & Education;;Tools & Equipment;;Candles & Holders;;Panties;;Pants;;Scarf;;Makeup Brushes & Tools;;Change Purse;;Button-Front;;Blankets & Throws;;Office supplies;;Leather;;Scoop Neck;;Hair Color;;Print;;Training Pants;;Bathroom Safety;;Action Figur ...
# =============
# Teethers;;Playards;;Epilators;;Sweatercoat;;Rainwear;;Needlecraft;;Bedspreads & Coverlets;;Dehumidifiers;;Humidifiers;;Paperweights;;Papermaking;;other
# =============

# %%
all_categories_labels_dbscam = DBSCAN().fit_predict(X)
Counter(all_categories_labels_dbscam)
# Counter({-1: 898, 0: 12})
# Out:
# Counter({-1: 898, 0: 12})

# %%
df_cat = pd.DataFrame(all_categories_labels_dbscam, index=all_categories, columns=['label'])
print(list(df_cat[df_cat['label'] == 0].index))
# ['Teethers', 'Playards', 'Epilators', 'Sweatercoat', 'Rainwear', 'Needlecraft', 'Bedspreads & Coverlets', 'Dehumidifiers', 'Humidifiers', 'Paperweights', 'Papermaking', 'other']
# Out:
# ['Teethers', 'Playards', 'Epilators', 'Sweatercoat', 'Rainwear', 'Needlecraft', 'Bedspreads & Coverlets', 'Dehumidifiers', 'Humidifiers', 'Paperweights', 'Papermaking', 'other']

# %% [markdown]
# # PCA

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.decomposition import PCA

def draw_PCA(X, Y, title):
    fig = plt.figure(1, figsize=(8, 6))
    ax = Axes3D(fig, elev=-150, azim=110)

    X_reduced = PCA(n_components=3).fit_transform(X)
    ax.scatter(X_reduced[:, 0], X_reduced[:, 1], X_reduced[:, 2], c=Y,
               cmap=plt.cm.Set1, edgecolor='k', s=40)
    ax.set_title(title)
    ax.set_xlabel("1st eigenvector")
    ax.w_xaxis.set_ticklabels([])
    ax.set_ylabel("2nd eigenvector")
    ax.w_yaxis.set_ticklabels([])
    ax.set_zlabel("3rd eigenvector")
    ax.w_zaxis.set_ticklabels([])

    plt.show()

# %%
draw_PCA(X, all_categories_labels_kmeans, 'kmeans')

# %%
draw_PCA(X, all_categories_labels_single, 'single link')

# %%
draw_PCA(X, all_categories_labels_average, 'average link')

# %%
draw_PCA(X, all_categories_labels_complete, 'complete link')

# %%
draw_PCA(X, all_categories_labels_dbscan, 'dbscan')

# %% [markdown]
# # Evaluation

# %%
df_cat = pd.DataFrame(all_categories_labels_kmeans, index=all_categories, columns=['label'])
for i in range(len(set(all_categories_labels_kmeans))):
    cats = list(df_cat[df_cat['label'] == i].index)    
    print("cluster " + str(i) + ": ")
    print(list(cats))
    print("=============================================")
    print("=============================================")
# Out:
# cluster 0:
# ['Monitors', 'Thermometers', 'Garbage Disposals', 'Amplifiers & Effects', 'Toothbrushes', 'Sponges', 'Camcorders', 'Tweezers', 'Mules & Clogs', 'Tripods & Supports', 'Tricycles, Scooters & Wagons', 'Slipcovers', 'Conditioners', 'Backpacks & Carriers', 'Mopping', 'Televisions', 'Motorcycle & Powersports', 'Air Purifiers', 'Prams', 'Cables & Adapters', 'Stringed Instruments', 'Harnesses & Leashes', 'Guitars', 'Lithographs, Etchings & Woodcuts', 'Fireplaces & Accessories', 'Clocks', 'Batteries', 'Binoculars & Telescopes', 'Air Fresheners', 'Humidifiers & Vaporizers', 'Soaps & Cleansers', 'Cleansers', 'Microwaves', 'Prenatal Monitoring Devices', 'Walkers', 'Headsets', 'Shampoos', 'Strollers', 'Refrigerators', 'Powders & Lotions', 'Flare', 'Computers & Tablets', 'Laptops & Netbooks', 'Keyboards', 'Potties & Seats', 'Wind & Woodwind Instruments', 'Swings, Jumpers & Bouncers', 'Air Conditioners', 'Chargers & Cradles', 'Printers, Scanners & Supplies', 'Washers & Dryers', 'Gates & Doorways']
# =============================================
# =============================================
# cluster 1:
# ['Books', 'Arts & Crafts', 'Education & Teaching', 'Arts & Photography', 'Christian Books & Bibles', 'Writing', 'Nonfiction', 'Instructional', 'Presentation', 'Puzzle', 'Art', 'Learning & Education', 'Action Figure', 'Film Photography', 'Religion', 'Biography', 'Sports Nutrition', 'Politics & Social Sciences', 'Scifi', 'Strategy Guides', 'Action, Adventure', 'Sci-Fi, Fantasy', 'eBook Access', 'Journal', "Children's Books", 'Science', 'Fitness technology', 'Poetry', 'Lifestyle & Cultures', 'Instrument', 'Religion & Spirituality', 'Guest Books', 'Musical instruments', 'Illustrated', 'Action Figures & Statues', 'Educational', 'Animation', 'Literature & Fiction', 'Medical Books', 'Science & Math', 'Price Guides & Publications', 'History', 'Fiction', 'Reference', 'Book', 'eBook Readers', 'Books and Zines', 'Comic', 'Comics']
# =============================================
# =============================================
# cluster 2:
# ['Quilts', 'Dusting', 'Diapering', 'Knitting Supplies', 'Puzzles', 'Baskets & Bins', 'Yarn', 'Oils & Fluids', 'Crafting', 'Teapot', 'Bakeware', 'Grooming', 'Toiletry Kits', 'Vases', 'Knitting', 'Geekery', 'Brushes & Applicators', 'Jewelry Boxes & Organizers', 'Brass Instruments', 'Glassware', 'Bouquets', 'Dolls and Miniatures', 'Cookbook', 'Nursery', 'Nursery Bedding', 'Carving', 'Cookware', 'Snowsuits & Bibs', 'Ceramics and Pottery', 'Biographies & Memoirs', 'Candles & Holders', 'Diaper Pails & Refills', 'Sculptures', 'Washcloths & Towels', 'Paper Ephemera', 'Tiles', 'Ornaments', 'Origami', 'Hobbies', 'Scale Dollhouse Miniature', 'Breastfeeding', 'Bedding', 'Scrapbooking', 'Flatware', 'Pillows & Stools', 'Draft Stoppers', 'Decorating', 'Sewing', 'Planter', 'Baskets', 'Figurines', 'Comforters & Sets', 'Kitchen Utensils & Gadgets', 'Cloth Diapers', 'Woodworking', 'Dinnerware Set', 'Decorative Pillows, Inserts & Covers', 'Irons & Ironing Boards', 'Disposable Diapers', 'Tumbler', 'Kitchen Knives & Cutlery Accessories', 'Sheets & Pillowcases', 'Printmaking', 'Garment Steamers', 'Stationery', 'Pacifiers & Accessories', 'Decorative Pillows', 'Primitive', 'Seasonal Décor', 'Nursery Décor', 'Racks, Shelves & Drawers', 'Diaper Stackers & Caddies', 'Coasters', 'Planters', 'Carpenter, Utility', 'Collectibles', 'Breastfeeding Pillows & Stools', 'Inflatable Beds']
# =============================================
# =============================================
# cluster 3:
# ['Track & Sweat Suits', 'Full-Length', 'Eyes', 'Straight, Pencil', 'Face', 'Feet', 'V-Neck', 'Button', 'Ring', 'Three Button', 'Lips', 'Tank', 'Slim, Skinny', 'Change Purse', 'Button-Front', 'Scoop Neck', 'Paper', 'Hands & Nails', 'Track Jacket', 'One Button', 'Two Button', 'Block', 'Cuff Links', 'Cross Stitch', 'Button Down Shirt', 'Seat Covers', 'Rings', 'Wall Hanging', 'Boot Cut', 'Full Skirt', 'Above Knee, Mini', 'Straight Leg', 'Track & Sweat Pants', 'Clock', 'Dress - Flat Front', 'Wide Leg', 'Light', 'Classic, Straight Leg', 'Knee-Length', 'Hip Bag', 'Sets']
# =============================================
# =============================================
# cluster 4:
# ['Skirt', 'Dresses', 'Leggings', 'Vest', 'Sweatshirt, Pullover', 'Jeans', 'Fashion Sneakers', 'Jerseys', 'Sweater', 'Blouse', 'Dress Suit', 'Tops & T-Shirts', 'Jackets', 'Apparel', 'Jacket', 'Suits & Blazers', 'Denim', 'Polo', 'Sandals', 'Cleats', 'Jean Jacket', 'Coats & Jackets', 'Boots', 'Capris, Cropped', 'Panties', 'Pants', 'Scarf', 'Dress Shorts', 'Suits', 'Bras', 'Sweats & Hoodies', 'Casual Shorts', 'Cardigan', 'Shirts & Tops', 'Tracksuits & Sweats', 'Dress Shirts', 'Tops', 'Tshirt', 'Thermal Underwear', 'Pants, Tights, Leggings', 'Pant Suit', 'Shirt', 'Blazer', 'Socks', 'Skirts, Skorts & Dresses', 'Hoodie', 'Dress', 'Dress Pants', "Women's Handbags", 'Underwear', 'Skirt Suit', 'Clothing', 'Capri, Cropped', 'Hats', 'Tops & Blouses', 'Sunglasses', 'Board Shorts', 'Skirts', 'Casual Pants', 'Shoes', 'Sweaters', 'Bottoms', 'Shorts', 'Polo Shirt', 'Khakis, Chinos', 'Flats', 'Lingerie', 'Vest, Sleeveless', 'Slippers', 'Fleece Jacket', 'Baggy, Loose']
# =============================================
# =============================================
# cluster 5:
# ['Waxing', 'Hair Relaxers', 'Nail Care', 'Exercise', 'Pregnancy & Maternity', 'Scrubs & Body Treatments', 'Bathing & Skin Care', 'Makeup Palettes', 'Changing Pads & Covers', 'Brushes', 'Yoga & Pilates', 'Hair Loss Products', 'Shampoo Plus Conditioner', 'Shampoo', 'Paint, Body & Trim', 'Makeup Brushes & Tools', 'Hair Color', 'Trim', 'Makeup Sets', 'Hair Perms & Texturizers', 'Nails', 'Body', 'Makeup Remover', 'Hair Coloring Tools', 'Hair & Scalp Treatments', 'Relaxed', 'Hair Care', 'Hair', 'Makeup', 'Bath & Body', 'Hair Accessories', 'Hair Styling Tools', 'Skin Care', 'Beauty', 'Window Treatments', 'Shampoo & Conditioner Sets']
# =============================================
# =============================================
# cluster 6:
# ['Storage & Organization', 'Car Electronics & Accessories', 'Studio Recording Equipment', 'Coaster', 'Equipment', 'Storage & Containers', 'Garage Storage & Organization', 'Home Decor', 'Car Subwoofers', 'Food Service Equipment & Supplies', 'Kitchen Safety', 'Kitchen Storage & Organization', 'RV Parts & Accessories', 'Outdoor', 'Home Décor', 'Replacement Parts', 'Space Heaters', 'Home Décor Accents', 'Travel Systems', 'Dining & Entertaining', 'Cleaning', 'Outdoor Safety', "Kids' Furniture", 'Tools & Equipment', 'Office supplies', 'Bathroom Safety', 'Bicycle Child Seats & Trailers', 'Other Furniture', 'Small Appliances', 'Car Seats', 'Electronic', 'Home Office Furniture', 'Daily & Travel items', 'Holiday Décor Storage', 'Bathroom Storage & Organization', 'Cell Phones & Accessories', "Kids' Room Décor", 'Electronics for Kids', 'Bedroom Furniture', 'Storage Cabinets', 'Headphones', 'Home Bar Furniture', 'Home Appliances', 'Car Speakers & Systems', 'GPS Units & Equipment', 'Kitchen Appliances', 'Basic Supplies', 'Automotive', 'Vacuums & Floor Care', 'Other Accessories', 'Beach Accessories', 'Car Stereos & Components', 'Cleaning Supplies', 'Networking & Connectivity', 'Grooming & Healthcare Kits', 'Laundry Storage & Organization', 'Household Cleaners', 'Electronics', 'Storage Solutions', 'Furniture', 'Office', "Kids' Furniture, Décor & Storage", 'Car', 'Area Rugs & Pads', 'Components & Parts', 'Living Room Furniture', 'Lighting & Studio', 'Home Speakers & Subwoofers', 'Household Supplies', 'Storage', 'Home Entertainment Furniture', 'Trash & Recycling', 'Nursery Furniture', 'Car Seats & Accessories', 'Car Security & Convenience', 'Replacement Parts & Tools', 'Bathroom Furniture Sets', 'Travel Beds', 'Tires & Wheels', 'Wine Accessories', 'Bathroom Accessories', 'Drives, Storage & Media', 'Building Toys', 'Standard', 'Highchairs & Booster Seats', 'Shopping Cart Covers', 'Clothing & Closet Storage']
# =============================================
# =============================================
# cluster 7:
# ['TV, Audio & Surveillance', 'Laptop', 'DVD & Blu-ray Players', 'Radio', 'Humor', 'Patch', 'Full Zip', 'Bass Guitars', 'Pin', 'Magic', 'Car Video', 'Video Game', 'Cell Phone Accessories', 'Toy Remote Control & Play Vehicles', 'DVD', 'Video Gaming Merchandise', 'Portable Audio & Accessories', 'Tablet', 'Camera', 'Band & Orchestra', 'Toy', 'Pad', 'Case', 'Video Games & Consoles', 'Cover-Ups', 'Gadget', 'Poster', 'Tape', 'Backpack Style', 'Videogame', 'Cell Phones & Smartphones', 'Media', 'Car Audio, Video & GPS', 'Box', 'Telephone', 'iPad', 'Horror', 'VHS', 'Mini', 'Television', 'Blu-Ray', 'Mixed Media', 'Cases, Covers & Skins', 'DJ, Electronic Music & Karaoke', 'Digital Cameras', 'Home Audio', 'Notebook', 'Tag', 'CD', 'Consoles']
# =============================================
# =============================================
# cluster 8:
# ['Wallet', 'Luggage', 'Motorcycle', 'Gloves', 'Pouch', 'Magnet', 'Lightweight', 'Diaper Bags', 'Pumps', 'Double Breasted', 'Cosmetic Bags', 'Wallets', 'Maternity Pillows', 'Wristlet', 'Leather', 'Wipes & Holders', 'Loafers & Slip-Ons', 'Lanyard', 'Collar', 'Chain', 'Purse', 'Playard Bedding', 'Maternity', 'Leg Warmers', 'Clutch', 'Diaper Bag', 'Mattress Pads', 'Satchel', 'Handbag', 'Leash', 'Cowl Neck', 'Belt', 'Apron', 'Backpacks, Bags & Briefcases', 'Tote', 'Dress - Pleat', 'Buckle', 'Hobo', 'Cabinet Locks & Straps', 'Pattern', 'Messenger & Crossbody', 'Bags and Purses', 'Shoulder Bag', 'Watches', 'Backpack', 'Pinback Button', 'Belts']
# =============================================
# =============================================
# cluster 9:
# ['Small Animal', 'Pets', 'Animals', 'Plush', 'Toddler', 'Animal', 'Art Doll', 'Human Figure Doll', 'Doll Clothing', 'Cage', 'Pet Lover', 'Toys', 'Outdoors', 'Fishing', 'Novelty & Gag Toys', 'Baby & Toddler Toys', 'Stuffed Animals & Plush', 'Costume', 'Doll', "Kids' Bedding", 'Doll Clothes', 'Feeding', 'Pet Supplies', 'Dogs']
# =============================================
# =============================================
# cluster 10:
# ['Crewneck', 'Turtleneck', 'Felted', 'Tiered', 'Hooded', 'Patchwork', 'Tuxedo', 'Joggers', 'Trench', 'Overalls', 'Collared', 'Puffer', 'Peasant', 'Patriotic', 'Asymmetrical', 'Peacoat', 'Wool', 'Footwear', 'Teacup', 'Turtleneck, Mock', 'Scarves & Wraps', 'Hawaiian', 'Tunic', 'Shrug', 'Necktie', 'Windbreaker', 'Tapestries', 'Corset', 'Pleated', 'Linen', 'Beading', 'Housewares', 'Outerwear', 'Needlepoint', 'Novelty', 'Swimwear', 'Linens', 'Raincoat', 'Oxfords', 'Henley', 'Corduroys', 'Halter', 'Handkerchief', 'Vests']
# =============================================
# =============================================
# cluster 11:
# ['Track & Field', 'Hockey', 'Bowl', 'Team Sports', 'MLB', 'NBA', 'Games', 'Game', 'Football', 'Pitcher', 'Cup', 'Outdoor Games', 'Baseball & Softball', 'Baseball', 'Sports & Outdoor Play', 'Sports', 'Soccer', 'NHL', 'Fantasy', 'NFL', 'NCAA', 'Basketball']
# =============================================
# =============================================
# cluster 12:
# ['Favors', 'Calendars', 'Trading Cards', 'Weddings', 'Supplies', 'Paper Goods', 'Totes & Shoppers', 'Boxes', 'Home Fragrance', 'Thanksgiving', 'School Supplies', 'Bags & Cases', 'Halloween', 'Holidays', 'Shipping Supplies', 'Calendar', 'Gift Wrap', 'Christmas', 'Valentine', 'Invitations', 'Easter', 'Stationery & Party Supplies', 'Stamps', 'Gift Sets', 'Decorations', 'Cards', 'Party Supplies']
# =============================================
# =============================================
# cluster 13:
# ['Girls', 'Water Sports', 'Fan Shop', 'Kids', 'Business & Money', 'Dress Up & Pretend Play', 'Sleep Positioners', 'Watch', 'Boys', '50 To 75 Years', 'Desktops & All-In-Ones', 'A-Line', 'Women', "New Year's", 'Home', 'Finding', 'Boys 2T-5T', "Kids' Home Store", 'Day of the Dead', 'Music', "St Patrick's", 'Other', '75 To 100 Years', 'Sun', 'Dance', 'Baby Gyms & Playmats', 'Top & T-shirts', 'Men', 'T-Shirts', 'Personal Care', 'House', 'One-Piece', 'Live Sound & Stage', 'Birthday', 'Baby & Child Care', 'Fans', "Kids' Bath", 'Health & Baby Care', 'Boys (4+)', 'All Other Sports', 'Child Friendly', 'Two-Piece', 'Food', 'Car Care', 'Girls 0-24 Mos', 'Girls 2T-5T', 'Girls (4+)', 'T-shirts', 'Boys 0-24 Mos', '100 Years or Older', 'How to', 'One-Pieces', 'Baby', 'Baby Seats', 'Something Blue', 'Boyfriend', 'Others']
# =============================================
# =============================================
# cluster 14:
# ['Charm', 'Beads', 'Bracelet', 'Handmade', 'Vintage & Collectibles', 'Bead', 'Ceramic', 'Earrings', 'Vase', 'Cabochon', 'Jewelry', 'Brooch', 'Keychain', 'Antique', 'Necklace', 'Necklaces', 'Figurine', 'Crochet', 'Fabric', 'Pendant', 'Vintage', 'Bracelets', 'Personalized', 'Fabric Postcard', 'Embroidery', 'Porcelain', 'Shawl']
# =============================================
# =============================================
# cluster 15:
# ['Kitchen', 'Plate', 'Coffee & Tea Accessories', 'Pot Holder', 'Shams, Bed Skirts & Bed Frame Draperies', 'Bubble Bath', 'Bath Linen Sets', 'Bath', 'Cream and Sugar Set', 'Water Coolers & Filters', 'Candle Holder', 'Bottle-Feeding', 'Trash Bags', 'Blankets & Throws', 'Mug', 'Dishes', 'Stained Glass', 'Kitchen & Table Linens', 'Glass', 'Paper Towels', 'Bath Rugs', 'Bottles', 'Duvet Covers & Sets', 'Home Brewing & Wine Making', 'Salt and Pepper Shakers', 'Pillow', 'Table', 'Pillows', 'Tray', 'Bathroom', 'Bowls', 'Bathing Tubs & Seats', 'Candles', 'Kitchen & Dining', 'Wrap', 'Bed Pillows', 'Candles & Home Scents', 'Bed', 'Casserole', 'Non-Slip Bath Mats', 'Chair', 'Towels', 'Blanket', 'Cake Toppers', 'Bed in a Bag', 'Wine, Beer & Beverage Coolers', 'Freezers & Ice Makers', 'Bubble']
# =============================================
# =============================================
# cluster 16:
# ['Athletic Training', 'Golf', 'Golf Apparel', 'Hiking & Camping', 'Bike & Skate', 'Boxing & MMA', 'Lacrosse', 'Badminton', 'Golf Balls', 'Potty Training', 'Varsity', 'Blazers & Sport Coats', 'Athletic', 'Volleyball', 'Gear', 'Training Pants', 'Swim Trunks', 'Basket', 'Bowling', 'Tennis & Racquets', 'Swim Briefs', 'Knit Top', 'Sports Bras', 'Sport', 'Skateboard', 'Golf Bags', 'Indoor', 'Athletic Apparel', 'Ballet', 'Sports & Outdoors', "Women's Golf Clubs", 'Snowboard', 'Mid-Calf', "Men's Golf Clubs", 'Board, Surf', 'Drums & Percussion', 'Golf Shoes', 'Polo, Rugby', 'Hat']
# =============================================
# =============================================
# cluster 17:
# ['Medical Supplies & Equipment', 'Historical, Military', 'Safety Caps', 'Health', 'Home Surveillance', 'Afghan', 'Signs', 'Work & Safety', 'Sun Protection', 'Electrical Safety', 'Religious', 'Family Planning Tests', 'Safety', 'Children', 'Sweeping', 'Serving', 'Engineering & Transportation', 'Teething Relief', 'Military', 'Health Care', 'Activity Centers & Entertainers', 'Ties', 'Strength training', 'Flight', 'Bomber', 'Organization']
# =============================================
# =============================================
# cluster 18:
# ['Fragrance', 'Sticker', 'Photo Albums & Frames', "Men's Accessories", 'Changing Kits', 'GPS Accessories & Mounts', 'Lighting', 'Paintings', 'Flashes & Flash Accessories', 'Advertisement', 'Lights & Lighting Accessories', 'Frame', "Women's Accessories", 'Travel Bathing Kits', 'Magazines', 'Accessories', 'Print', 'Patterns', 'Photographs', 'Graphic Design', 'Styling Tools', 'Mirrors', 'Interior Accessories', 'Magnets', 'Eyewear', 'Microphones & Accessories', 'Artwork', 'Cameras & Photography', 'Lenses & Filters', 'Accessory', 'Automotive Enthusiast Merchandise', 'Lamps& Accessories', 'Camera & Photo Accessories', 'Collages', 'Frames', 'Exterior Accessories', 'Bookmark', 'Nail Tools', 'Styling Products', 'Drawings', 'Dolls & Accessories', 'Illustration', 'Custom', 'Fitness accessories', 'Instrument Accessories', 'Postcard', 'Photography', 'Bathing Accessories', 'Posters & Prints', 'Gadgets', 'Vinyl', 'Aceo', 'Painting', 'Screen Protectors', 'Ink & Toner', 'Sets & Kits', 'Wall Decor', 'Tools & Accessories', 'Performance Parts & Accessories']
# =============================================
# =============================================
# cluster 19:
# ['Teethers', 'Baguette', 'Playards', 'Epilators', 'Cargo', 'Sweatercoat', 'Rainwear', 'Needlecraft', 'Bedspreads & Coverlets', 'Dehumidifiers', 'Nasal Aspirators', 'Maxi', 'Carpenter', 'Tank, Cami', 'Humidifiers', 'Parka', 'Souvenir', 'Asymmetrical Hem', 'Fixture', 'Formal', 'Cape', 'Paperweights', 'Poncho', 'Papermaking', 'G-Strings & Thongs', 'other']
# =============================================
# =============================================

# %%
df_cat = pd.DataFrame(all_categories_labels_single, index=all_categories, columns=['label'])
for i in range(len(set(all_categories_labels_kmeans))):
    cats = list(df_cat[df_cat['label'] == i].index)    
    print("cluster " + str(i) + ": ")
    print(sorted(list(cats)))
    print("=============================================")
    print("=============================================")
# Out:
# cluster 0:
# ['Athletic', 'Athletic Apparel', 'Athletic Training', 'Badminton', 'Ballet', 'Band & Orchestra', 'Basket', 'Bass Guitars', 'Bike & Skate', 'Board Shorts', 'Board, Surf', 'Bowling', 'Boxing & MMA', 'Brass Instruments', 'Cargo', 'Casual Pants', 'Casual Shorts', 'Coaster', 'Coasters', 'Cup', 'Drums & Percussion', 'Fishing', 'Formal', 'Gear', 'Golf', 'Golf Apparel', 'Golf Bags', 'Golf Balls', 'Golf Shoes', 'Guitars', 'Hiking & Camping', 'Indoor', 'Instrument', 'Leash', 'Maxi', "Men's Golf Clubs", 'Motorcycle', 'Motorcycle & Powersports', 'Musical instruments', 'Outdoor', 'Outdoor Games', 'Outdoors', 'Polo', 'Polo, Rugby', 'Poncho', 'Skateboard', 'Snowboard', 'Sports & Outdoor Play', 'Sports & Outdoors', 'Stringed Instruments', 'Swim Briefs', 'Swim Trunks', 'Tennis & Racquets', 'Track & Field', 'Training Pants', 'Tweezers', 'Water Sports', 'Wind & Woodwind Instruments', "Women's Golf Clubs", 'Yoga & Pilates']
# =============================================
# =============================================
# cluster 1:
# ['Afghan', 'Arts & Crafts', 'Bomber', 'Education & Teaching', 'Educational', 'Exercise', 'Fitness technology', 'Historical, Military', 'History', 'Learning & Education', 'Lifestyle & Cultures', 'Military', 'Organization', 'Patriotic', 'Peasant', 'Politics & Social Sciences', 'Potty Training', 'Presentation', 'Religion', 'Religion & Spirituality', 'Religious', 'Science', 'Science & Math', 'Sports Nutrition', 'Strength training', 'Writing']
# =============================================
# =============================================
# cluster 2:
# ['Aceo', 'Baguette', 'Bakeware', 'Baskets', 'Baskets & Bins', 'Bedding', 'Bookmark', 'Bouquets', 'Bras', 'Cake Toppers', 'Calendar', 'Calendars', 'Carpenter', 'Carpenter, Utility', 'Carving', 'Casserole', 'Ceramic', 'Ceramics and Pottery', 'Cookbook', 'Cookware', 'Crafting', 'Crochet', 'Decorating', 'Decorations', 'Diapering', 'Dolls and Miniatures', 'Drawings', 'Embroidery', 'Figurine', 'Figurines', 'Flatware', 'Garment Steamers', 'Gates & Doorways', 'Geekery', 'Glassware', 'Hawaiian', 'Housewares', 'Humidifiers & Vaporizers', 'Invitations', 'Knitting', 'Knitting Supplies', 'Linens', 'Lithographs, Etchings & Woodcuts', 'Mug', 'Needlepoint', 'Novelty', 'Novelty & Gag Toys', 'Nursery', 'Nursery Bedding', 'Nursery Décor', 'Nursery Furniture', 'Origami', 'Ornaments', 'Paintings', 'Patchwork', 'Pattern', 'Patterns', 'Pendant', 'Personalized', 'Photographs', 'Planter', 'Planters', 'Playard Bedding', 'Plush', 'Porcelain', 'Postcard', 'Primitive', 'Printmaking', 'Quilts', 'Scale Dollhouse Miniature', 'Scrapbooking', 'Sculptures', 'Seasonal Décor', 'Sewing', 'Snowsuits & Bibs', 'Souvenir', 'Sports Bras', 'Stationery', 'Stuffed Animals & Plush', 'Tapestries', 'Teacup', 'Teapot', 'Tiles', 'Toiletry Kits', 'Totes & Shoppers', 'Tripods & Supports', 'Tumbler', 'Vase', 'Vases', 'Walkers', 'Woodworking', 'Yarn']
# =============================================
# =============================================
# cluster 3:
# ['Backpacks & Carriers', 'Batteries', 'Binoculars & Telescopes', 'Brushes', 'Brushes & Applicators', 'Cables & Adapters', 'Camcorders', 'Cell Phones & Smartphones', 'Chargers & Cradles', 'Cloth Diapers', 'Computers & Tablets', 'Diaper Pails & Refills', 'Diaper Stackers & Caddies', 'Disposable Diapers', 'Dusting', 'Gadgets', 'Garbage Disposals', 'Grooming', 'Harnesses & Leashes', 'Headsets', 'Irons & Ironing Boards', 'Keyboards', 'Laptops & Netbooks', 'Microwaves', 'Monitors', 'Mopping', 'Mules & Clogs', 'Potties & Seats', 'Prams', 'Printers, Scanners & Supplies', 'Refrigerators', 'Slipcovers', 'Sponges', 'Strollers', 'Sweeping', 'Swings, Jumpers & Bouncers', 'Televisions', 'Thermometers', 'Tricycles, Scooters & Wagons', 'Washers & Dryers']
# =============================================
# =============================================
# cluster 4:
# ['Apron', 'Asymmetrical', 'Asymmetrical Hem', 'Beading', 'Capri, Cropped', 'Capris, Cropped', 'Collared', 'Corduroys', 'Corset', 'Crewneck', 'Flare', 'Halter', 'Handbag', 'Handkerchief', 'Henley', 'Hobo', 'Hooded', 'Joggers', 'Keychain', 'Khakis, Chinos', 'Lanyard', 'Lightweight', 'Linen', 'Magnet', 'Messenger & Crossbody', 'Necktie', 'Overalls', 'Peacoat', 'Pleated', 'Pouch', 'Puffer', 'Relaxed', 'Satchel', 'Shawl', 'Shrug', 'Sweatshirt, Pullover', 'Tiered', 'Tote', 'Trench', 'Tunic', 'Turtleneck', 'Turtleneck, Mock', 'Tuxedo', 'Windbreaker', 'Wool', 'Wristlet']
# =============================================
# =============================================
# cluster 5:
# ['Apparel', 'Belt', 'Blazer', 'Blazers & Sport Coats', 'Blouse', 'Boots', 'Bottoms', 'Buckle', 'Cabinet Locks & Straps', 'Cardigan', 'Cleats', 'Clothing', 'Coats & Jackets', 'Denim', 'Dress', 'Dress - Pleat', 'Dress Pants', 'Dress Shirts', 'Dress Shorts', 'Dress Suit', 'Dresses', 'Fashion Sneakers', 'Flats', 'Fleece Jacket', 'Footwear', 'Gloves', 'Hat', 'Hats', 'Hoodie', 'Jacket', 'Jackets', 'Jean Jacket', 'Jeans', 'Jerseys', 'Leggings', 'Lingerie', 'Loafers & Slip-Ons', 'Outerwear', 'Oxfords', 'Pant Suit', 'Pants', 'Pants, Tights, Leggings', 'Parka', 'Polo Shirt', 'Pumps', 'Sandals', 'Scarf', 'Scarves & Wraps', 'Shirt', 'Shirts & Tops', 'Shoes', 'Shorts', 'Skirt', 'Skirt Suit', 'Skirts', 'Skirts, Skorts & Dresses', 'Slippers', 'Socks', 'Suits', 'Suits & Blazers', 'Sweater', 'Sweaters', 'Sweats & Hoodies', 'Swimwear', 'Ties', 'Tops', 'Tops & Blouses', 'Tracksuits & Sweats', 'Tshirt', 'Vest', 'Vest, Sleeveless', 'Vests', 'Watches', 'Weddings']
# =============================================
# =============================================
# cluster 6:
# ['Accessory', 'Action Figures & Statues', 'Activity Centers & Entertainers', 'Art', 'Arts & Photography', 'Automotive', 'Automotive Enthusiast Merchandise', 'Camera', 'Camera & Photo Accessories', 'Cameras & Photography', 'Car', 'Car Care', 'Car Electronics & Accessories', 'Car Seats', 'Car Seats & Accessories', 'Car Security & Convenience', 'Car Speakers & Systems', 'Car Stereos & Components', 'Car Subwoofers', 'Cards', 'Case', 'Cases, Covers & Skins', 'Cell Phone Accessories', 'Cell Phones & Accessories', 'Changing Kits', 'Changing Pads & Covers', 'Clock', 'Clocks', 'Components & Parts', 'Cover-Ups', 'Draft Stoppers', 'Drives, Storage & Media', 'Electronic', 'Electronics', 'Favors', 'Film Photography', 'Fitness accessories', 'Flashes & Flash Accessories', 'Flight', 'Freezers & Ice Makers', 'Full Zip', 'Full-Length', 'GPS Accessories & Mounts', 'GPS Units & Equipment', 'Gadget', 'Graphic Design', 'Grooming & Healthcare Kits', 'Hair Coloring Tools', 'Hair Styling Tools', 'Headphones', 'Highchairs & Booster Seats', 'Home Speakers & Subwoofers', 'Home Surveillance', 'Ink & Toner', 'Instrument Accessories', 'Laptop', 'Makeup Brushes & Tools', 'Mini', 'Nail Tools', 'Networking & Connectivity', 'Notebook', 'Office', 'Pad', 'Paper', 'Paper Ephemera', 'Paper Goods', 'Paper Towels', 'Performance Parts & Accessories', 'Photography', 'Portable Audio & Accessories', 'Prenatal Monitoring Devices', 'Price Guides & Publications', 'RV Parts & Accessories', 'Replacement Parts', 'Replacement Parts & Tools', 'Safety Caps', 'Screen Protectors', 'Sets', 'Sets & Kits', 'Signs', 'Space Heaters', 'Standard', 'Strategy Guides', 'Styling Products', 'Styling Tools', 'Tablet', 'Telephone', 'Tires & Wheels', 'Tools & Accessories', 'Toy Remote Control & Play Vehicles', 'Trading Cards', 'iPad']
# =============================================
# =============================================
# cluster 7:
# ['100 Years or Older', '50 To 75 Years', '75 To 100 Years', 'All Other Sports', 'Baby', 'Baby & Child Care', 'Birthday', 'Boyfriend', 'Boys', 'Boys (4+)', 'Boys 2T-5T', 'Business & Money', 'Christmas', 'Day of the Dead', 'Desktops & All-In-Ones', 'Easter', 'Family Planning Tests', 'Food', 'Girls', 'Girls (4+)', 'Girls 2T-5T', 'Health', 'Health & Baby Care', 'Health Care', 'Holidays', 'Home', 'House', 'How to', "Kids' Home Store", "New Year's", 'Other', 'Others', 'Personal Care', 'Thanksgiving', 'Valentine', 'Work & Safety']
# =============================================
# =============================================
# cluster 8:
# ['Bath', 'Bath & Body', 'Bathing & Skin Care', 'Beauty', 'Bed', 'Bed Pillows', 'Bed in a Bag', 'Body', 'Bottles', 'Bubble', 'Bubble Bath', 'Candles', 'Candles & Home Scents', 'Coffee & Tea Accessories', 'Cream and Sugar Set', 'Eyes', 'Feet', 'Gift Sets', 'Gift Wrap', 'Hair', 'Hair Accessories', 'Hair Care', 'Hair Color', 'Hair Loss Products', 'Hands & Nails', 'Home Brewing & Wine Making', 'Home Fragrance', "Kids' Bath", 'Light', 'Lips', 'Nail Care', 'Nails', 'Paint, Body & Trim', 'Shams, Bed Skirts & Bed Frame Draperies', 'Skin Care', 'Sleep Positioners', 'Sun', 'Sun Protection', 'Wine Accessories', 'Wine, Beer & Beverage Coolers']
# =============================================
# =============================================
# cluster 9:
# ['Accessories', 'Bathing Accessories', 'Beach Accessories', 'Custom', 'Dolls & Accessories', 'Exterior Accessories', 'Eyewear', 'Fabric', 'Fabric Postcard', 'Fireplaces & Accessories', 'Fragrance', 'Frame', 'Frames', 'Glass', 'Interior Accessories', 'Lamps& Accessories', 'Leather', 'Lenses & Filters', 'Lighting', 'Lighting & Studio', 'Lights & Lighting Accessories', 'Magnets', 'Microphones & Accessories', 'Mirrors', 'Pacifiers & Accessories', 'Painting', 'Poster', 'Posters & Prints', 'Print', 'Raincoat', 'Stained Glass', 'Sunglasses', 'Toothbrushes', 'Travel Bathing Kits', 'Vinyl', 'Wall Decor', 'Wall Hanging']
# =============================================
# =============================================
# cluster 10:
# ['A-Line', 'Action Figure', 'Action, Adventure', 'Baby Gyms & Playmats', 'Baby Seats', 'Block', 'Blu-Ray', 'Boys 0-24 Mos', 'CD', 'Cage', 'Car Audio, Video & GPS', 'Car Video', 'DJ, Electronic Music & Karaoke', 'DVD', 'DVD & Blu-ray Players', 'Dance', 'Digital Cameras', 'Face', 'Fan Shop', 'Fans', 'Fantasy', 'Girls 0-24 Mos', 'Home Audio', 'Horror', 'Humor', 'Live Sound & Stage', 'Magic', 'Media', 'Men', 'Mixed Media', 'Music', 'Non-Slip Bath Mats', 'Pin', 'Radio', 'Sci-Fi, Fantasy', "St Patrick's", 'Studio Recording Equipment', 'T-Shirts', 'T-shirts', 'TV, Audio & Surveillance', 'Tag', 'Tank, Cami', 'Tape', 'Television', 'Top & T-shirts', 'Tops & T-Shirts', 'Toy', 'Video Game', 'Video Games & Consoles', 'Video Gaming Merchandise', 'Watch']
# =============================================
# =============================================
# cluster 11:
# ['Baseball', 'Baseball & Softball', 'Basketball', 'Bowl', 'Bowls', 'Football', 'Game', 'Games', 'Hockey', 'Lacrosse', 'MLB', 'NBA', 'NCAA', 'NFL', 'NHL', 'Pitcher', 'Soccer', 'Sport', 'Sports', 'Team Sports', 'Varsity', 'Volleyball']
# =============================================
# =============================================
# cluster 12:
# ['Antique', 'Bead', 'Beads', 'Bracelet', 'Bracelets', 'Brooch', 'Cabochon', 'Charm', 'Collectibles', 'Earrings', 'Felted', 'Handmade', 'Jewelry', 'Necklace', 'Necklaces', 'Vintage', 'Vintage & Collectibles']
# =============================================
# =============================================
# cluster 13:
# ['Air Conditioners', 'Air Fresheners', 'Air Purifiers', 'Amplifiers & Effects', 'Breastfeeding', 'Cape', 'Cleansers', 'Conditioners', 'Hair & Scalp Treatments', 'Hair Perms & Texturizers', 'Hair Relaxers', 'Makeup', 'Makeup Palettes', 'Makeup Remover', 'Makeup Sets', 'Maternity', 'Nasal Aspirators', 'Oils & Fluids', 'Panties', 'Powders & Lotions', 'Pregnancy & Maternity', 'Salt and Pepper Shakers', 'Scrubs & Body Treatments', 'Shampoo', 'Shampoo & Conditioner Sets', 'Shampoo Plus Conditioner', 'Shampoos', 'Soaps & Cleansers', 'Teething Relief', 'Thermal Underwear', 'Underwear', 'Water Coolers & Filters', 'Waxing', 'Window Treatments']
# =============================================
# =============================================
# cluster 14:
# ['Basic Supplies', 'Bathroom', 'Bathroom Accessories', 'Bathroom Furniture Sets', 'Bathroom Safety', 'Bathroom Storage & Organization', 'Bedroom Furniture', 'Bicycle Child Seats & Trailers', 'Bottle-Feeding', 'Chair', 'Cleaning', 'Cleaning Supplies', 'Clothing & Closet Storage', 'Dining & Entertaining', 'Dishes', 'Electrical Safety', 'Engineering & Transportation', 'Equipment', 'Feeding', 'Food Service Equipment & Supplies', 'Furniture', 'Garage Storage & Organization', 'Holiday Décor Storage', 'Home Appliances', 'Home Bar Furniture', 'Home Decor', 'Home Décor', 'Home Décor Accents', 'Home Entertainment Furniture', 'Home Office Furniture', 'Household Cleaners', 'Household Supplies', 'Inflatable Beds', "Kids' Furniture", "Kids' Furniture, Décor & Storage", "Kids' Room Décor", 'Kitchen', 'Kitchen & Dining', 'Kitchen & Table Linens', 'Kitchen Appliances', 'Kitchen Safety', 'Kitchen Storage & Organization', 'Laundry Storage & Organization', 'Living Room Furniture', 'Medical Supplies & Equipment', 'Office supplies', 'Other Furniture', 'Outdoor Safety', 'Party Supplies', 'Pet Supplies', 'Safety', 'School Supplies', 'Seat Covers', 'Serving', 'Shipping Supplies', 'Shopping Cart Covers', 'Small Appliances', 'Stationery & Party Supplies', 'Storage', 'Storage & Containers', 'Storage & Organization', 'Storage Cabinets', 'Storage Solutions', 'Supplies', 'Table', 'Tools & Equipment', 'Travel Beds', 'Travel Systems', 'Vacuums & Floor Care']
# =============================================
# =============================================
# cluster 15:
# ['Above Knee, Mini', 'Backpack', 'Backpack Style', 'Baggy, Loose', 'Boot Cut', 'Box', 'Button', 'Button Down Shirt', 'Button-Front', 'Candle Holder', 'Chain', 'Change Purse', 'Classic, Straight Leg', 'Clutch', 'Collar', 'Cowl Neck', 'Cross Stitch', 'Cuff Links', 'Dinnerware Set', 'Double Breasted', 'Dress - Flat Front', 'Dress Up & Pretend Play', 'Fixture', 'Full Skirt', 'G-Strings & Thongs', 'Hip Bag', 'Knee-Length', 'Knit Top', 'Leg Warmers', 'Mid-Calf', 'One Button', 'One-Piece', 'One-Pieces', 'Patch', 'Pinback Button', 'Plate', 'Pot Holder', 'Purse', 'Ring', 'Rings', 'Scoop Neck', 'Shoulder Bag', 'Slim, Skinny', 'Something Blue', 'Sticker', 'Straight Leg', 'Straight, Pencil', 'Tank', 'Three Button', 'Track & Sweat Pants', 'Track & Sweat Suits', 'Track Jacket', 'Tray', 'Trim', 'Two Button', 'Two-Piece', 'V-Neck', 'Wallet', 'Wide Leg', 'Wrap']
# =============================================
# =============================================
# cluster 16:
# ['Advertisement', 'Animation', 'Artwork', 'Biographies & Memoirs', 'Biography', 'Book', 'Books', 'Books and Zines', "Children's Books", 'Christian Books & Bibles', 'Collages', 'Comic', 'Comics', 'Consoles', 'Daily & Travel items', 'Fiction', 'Guest Books', 'Hobbies', 'Illustrated', 'Illustration', 'Instructional', 'Journal', 'Literature & Fiction', 'Magazines', 'Medical Books', 'Nonfiction', 'Photo Albums & Frames', 'Poetry', 'Puzzle', 'Puzzles', 'Reference', 'Scifi', 'VHS', 'Videogame', 'eBook Access', 'eBook Readers']
# =============================================
# =============================================
# cluster 17:
# ['Bedspreads & Coverlets', 'Dehumidifiers', 'Epilators', 'Humidifiers', 'Needlecraft', 'Papermaking', 'Paperweights', 'Playards', 'Rainwear', 'Sweatercoat', 'Teethers', 'other']
# =============================================
# =============================================
# cluster 18:
# ['Animal', 'Animals', 'Art Doll', 'Baby & Toddler Toys', 'Building Toys', 'Child Friendly', 'Children', 'Costume', 'Dogs', 'Doll', 'Doll Clothes', 'Doll Clothing', 'Electronics for Kids', 'Finding', 'Halloween', 'Human Figure Doll', 'Kids', "Kids' Bedding", "Men's Accessories", 'Other Accessories', 'Pet Lover', 'Pets', 'Small Animal', 'Toddler', 'Toys', 'Women', "Women's Accessories", "Women's Handbags"]
# =============================================
# =============================================
# cluster 19:
# ['Area Rugs & Pads', 'Backpacks, Bags & Briefcases', 'Bags & Cases', 'Bags and Purses', 'Bath Linen Sets', 'Bath Rugs', 'Bathing Tubs & Seats', 'Belts', 'Blanket', 'Blankets & Throws', 'Boxes', 'Breastfeeding Pillows & Stools', 'Candles & Holders', 'Comforters & Sets', 'Cosmetic Bags', 'Decorative Pillows', 'Decorative Pillows, Inserts & Covers', 'Diaper Bag', 'Diaper Bags', 'Duvet Covers & Sets', 'Jewelry Boxes & Organizers', 'Kitchen Knives & Cutlery Accessories', 'Kitchen Utensils & Gadgets', 'Luggage', 'Maternity Pillows', 'Mattress Pads', 'Pillow', 'Pillows', 'Pillows & Stools', 'Racks, Shelves & Drawers', 'Sheets & Pillowcases', 'Stamps', 'Towels', 'Trash & Recycling', 'Trash Bags', 'Wallets', 'Washcloths & Towels', 'Wipes & Holders']
# =============================================
# =============================================
